# %% [markdown]
# # Projectile Motion Simulation Notebook
#
# This notebook runs the existing Euler vs RK4 simulation and shows the printed results, plots, and animation in one place.
#
# Run the code cell below.
#
# If you want to change the angle, speed, drag, or timestep, edit `projectile-motion-simulation.py` first, then run the cell again.

# %%
# %matplotlib inline
# %run projectile-motion-simulation.py
